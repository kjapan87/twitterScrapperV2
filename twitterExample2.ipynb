# %% [markdown]
# <a href="https://colab.research.google.com/github/kjapan87/twitterScrapperV2/blob/main/twitterExample2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer

#Reading the data
MainData = pd.read_csv("/content/drive/My Drive/twitterData.csv", encoding = "ISO-8859-1", header = None)

#Classifying the raw data in dependent & independent variables
x = MainData.iloc[0:1599999,5].values
y = MainData.iloc[0:1599999,0].values

#preparing for the Pre-processing of the tweet's text data by calling nltk & it's classes
import nltk
import re
from bs4 import BeautifulSoup
from nltk.stem.porter import PorterStemmer
nltk.download("stopwords")
from nltk.corpus import stopwords

#starting the Pre-processing of the tweet's text data

corpus = []
for i in range(0,1000):
    tweet = re.sub("http\S+"," ", x[i])
    tweet = re.sub("@\S+", " ", x[i])
    tweet = re.sub("a-zA-Z"," ",x[i])
    tweet = tweet.lower()
    tweet = tweet.split()
    stemming = PorterStemmer()
    tweet = [stemming.stem(word) for word in tweet if not word in set(stopwords.words("english"))] 
    tweet = " ".join(tweet)
    corpus.append(tweet)

#Applying the model
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# ["@switchfoot http://twitpic.com/2y1zl - awww, that' bummer. shoulda got david carr third day it. ;d", "upset can't updat facebook text it... might cri result school today also. blah!", '@kenichan dive mani time ball. manag save 50% rest go bound', 'whole bodi feel itchi like fire', "@nationwideclass no, behav all. i'm mad. here? can't see there.", '@kwesidei whole crew', 'need hug', "@loltrish hey long time see! yes.. rain bit ,onli bit lol , i'm fine thank , how' ?", '@tatiana_k nope', '@twittera que muera ?', 'spring break plain city... snow', 're-pierc ear', '@caregiv bear watch it. thought ua loss embarrass . . . . .', '@octolinz16 counts, idk either. never talk anymor', "@smarrison would'v first, gun. realli though, zac snyder' doucheclown.", '@iamjazzyfizzl wish got watch you!! miss @iamlilnicki premiere?!', "hollis' death scene hurt sever watch film wri director cut now?", 'file tax', '@lettya ahh ive alway want see rent love soundtrack!!', '@fakerpattypattz oh dear. drink forgotten tabl drinks?', '@alydesign day get much done', "one friend call me, ask meet mid valley today...but i'v time *sigh*", '@angry_barista bake cake ate', 'week go hope', 'blagh class 8 tomorrow', 'hate call wake peopl', 'go cri sleep watch marley me.', 'im sad miss.lilli', 'ooooh.... lol leslie.... ok lesli get mad', 'meh... almost lover exception... track get depress everi time.', 'some1 hack account aim make new one', '@alielayu want go promot gear groov unforn ride may b go one anaheim may though', 'thought sleep option tomorrow realiz not. evalu morn work afternoon!', '@julieebabi awe love too!!!! 1 miss', '@humpninja cri asian eye sleep night', "ok i'm sick spent hour sit shower caus sick stand held back puke like champ. bed", '@cocomix04 ill tell ya stori later good day ill workin like three hours...', '@missxu sorry! bed time came (gmt+1) http://is.gd/fng', '@fleuryli either. depressing. think even want know kid suitcases.', "bed. class 8-12. work 12-3. gym 3-5 6. class 6-10. anoth day that' gonna fli by. miss girlfriend", 'realli feel like get today... got studi tomorrow practic exam...', "he' reason teardrop guitar one enough break heart", "sad, sad, sad. know hate feel wanna sleep still can't!", '@jonathanrknight awww soo wish see final comfortable! im sad miss', "fall asleep. heard traci girl' bodi found. sad heart break family.", "@viennah yay! i'm happi job! also mean less time you...", 'check user timelin blackberry, look like twank still happen ppl still prob w/ bg uids?', "oh man...wa iron @jeancjumbe' fave top wear meeting. burnt", 'strang sad lilo samro break up.', "@tea oh! i'm sorri think retweeting.", "broadband plan 'a massiv broken promise' http://tinyurl.com/dcuc33 via www.diigo.com/~tautao still wait broadband", "@localtweep wow, ton repli you, may unfollow see friends' tweets, scroll feed lot.", 'duck chicken take wayyy long hatch', 'put vacat photo onlin yr ago. pc crashed, forget name site.', 'need hug', '@andywana sure are, pos! much want to, dont think trade away compani asset sorri andy!', '@oanhlov hate happens...', 'sad feel dalla go show gotta say though, think show would use music game. mmm', 'ugh....92 degre tomorrow', 'u move to? thought u alreadi sd. ?? hmmm. random u found me. glad hear yer well.', "@batmanyng miss ps3, commiss wutcha playing? cop 'blood sand'?", 'leav park lot work!', 'life cool. me.', "sadli though, i'v never gotten experi post coitu cigarett before, never will.", 'nice day. bad rain come tomorrow 5am', "@starrbbi bad around lost job can't even pay phone bill lmao aw shuck", 'damm back school tomorrow', "mo jobs, money. hell min wage 4 f'n clam hour?", '@katortiz forever... see soon!', '@lt_algonquin agreed, saw failwhal allllll day today.', "@jdarter oh! haha... dude dont realli look em unless someon say hey ad you. sorri i'm terribl that. need pop up!", "@ninjen i'm sure right... need start work nikster... jare least!", 'realli hate peopl diss bands! trace clearli ugly!', 'gym attir to ...
